# %%
import pandas as pd

# %%
data_file = 'data/RSM-Ebner-Stolz-Data.xlsx'

# Replace 'output.csv' with the name you want for your CSV file.
csv_file = 'output.csv'

df = pd.read_excel(data_file)
df.to_csv(csv_file, index=False)
df
# Out:
#    Scenario: \n  \
# 0           NaN
# 1         Task:
# 2           NaN
# 3   Procedure:
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9           NaN
# 10          NaN
# 11          NaN
# 12          NaN
# 13          NaN
#
# ...
