# %%
import pandas as pd

# %%
data_file = 'data/easy.xlsx'

df = pd.read_excel(data_file)
df
# Out:
#     Konto                      Kontoname  Belegnummer Buchungsdatum Benutzer  \
# 0   13274  Sonstige Verbindlichkeiten 02     13048598    2021-01-31     SUMI
# 1   13274  Sonstige Verbindlichkeiten 02     17140478    2021-01-31     SUMI
# 2   13274  Sonstige Verbindlichkeiten 02     17417068    2021-02-14     SUMI
# 3   13274  Sonstige Verbindlichkeiten 02     17087026    2021-02-14     SUMI
# 4   13274  Sonstige Verbindlichkeiten 02     17800869    2021-03-20     SUMI
# 5   13274  Sonstige Verbindlichkeiten 02     14728436    2021-03-20     SUMI
# 6   13274  Sonstige Verbindlichkeiten 02     13703040    2021-04-03     SUMI
# 7   13274  Sonstige Verbindlichkeiten 02     15399198    2021-04-03     SUMI
# 8   13274  Sonstige Verbindlichkeiten 02     17538979    2021-04-22     ABMA
# 9   13274  Sonstige Verbindlichkeiten 02     17724099    2021-04-22     ABMA
# 10  13274  Sonstige Verbindlichkeiten 02     14898357    2021-05-07     SUMI
# ...
